# %% [markdown]
# # Mochila binária

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Obs.:**
# - Cada x (x0, x1, x2) representa um bloco diferente
# - x é binario porque ou é 0 ou é 1, ou seja, ou está dentro da mochila ou está fora

# %%
# %%writefile mochila.cpp
#
# #include<iostream>
# #include<vector>
# #include<algorithm>
# using namespace std;
#
# int main() {
#
#   vector<item> itens;
#
#   struct item {
#     int id;
#     double peso;
#     double valor;
#   } x0, x1, x2, x3, x4;
#
#   double pesoT = 0;
#   double valorT = 0;
#   double pesoLimite = 15;
#   vector<double> resposta;
#   int T; // numero de objetos selecionados
#
#   for (int i = 0; i < 5; i++) {
#     if (pesoT + item.peso[i]) <
#   }
#
#
# }

# %%
# %%writefile mochila.cpp
#
# #include <iostream>
# #include <vector>
# #include <algorithm>
#
# struct item{
#   int id;
#   double weight;
#   double value;
# };
#
# bool compare_value (item a,item b){
#   return a.value>b.value;
# }
#
#
# int main(){
#
#    std::vector<item> itens;
#    int N;
#    double W;
#
#    // LEITURA DA QUANTIDADE DE ITENS E CAPACIDADE DA MOCHILA
#    std::cin >> N >> W;
#
#    // LEITURA DOS ITENS
#    for (int i=0;i<N;i++){
#       item obj;
#       std::cin >> obj.weight >> obj.value;
#       itens.push_back(obj);
#    }
#
#    // ORDENA EM RELAĆÃO AO VALOR
#    std::sort(itens.begin(), itens.end(),compare_value);
#
#
#    return 0;
#
# }
# Out:
# Writing mochila.cpp

# %%
# !g++ -o mochila mochila.cpp

# %%
# !./mochila < "in1.txt" > "out1.txt"

# %% [markdown]
# -----
# Mais valioso primeiro

# %%
# %%writefile mochila.cpp
#
# #include <iostream>
# #include <vector>
# #include <algorithm>
#
# struct item{
#   int id;
#   double weight;
#   double value;
# };
#
# bool compare_value (item a,item b){
#   return a.value>b.value; // valor é prioridade
# }
#
#
# int main(){
#
#    std::vector<item> itens;
#    int N;
#    double W;
#
#    // LEITURA DA QUANTIDADE DE ITENS E CAPACIDADE DA MOCHILA
#    std::cin >> N >> W;
#
#    // LEITURA DOS ITENS
#    for (int i=0;i<N;i++){
#       item obj;
#       std::cin >> obj.weight >> obj.value;
#       itens.push_back(obj);
#    }
#
#    // ORDENA EM RELAĆÃO AO VALOR
#    std::sort(itens.begin(), itens.end(), compare_value);
#
#    // ORDENA DECRESCENTE EM RELAÇÃO AO VALOR
#    std::sort(itens.begin(), itens.end(), compare_value);
#
#    //CRIA MOCHILA
#    std::vector<int> moc;
#
#    std::vector<item> selected;
#
#    for (int i=0; i<N; i++)
#      if (itens[i].weight <= W) {
#        moc.push_back(itens[i].id);
#        W-=itens[i].weight;
#        // precisa colocar um std::cout
#        selected.push_back(itens[i]);
#      }
#      else break;
#
#     for (int s = 0; s < selected.size(); s++) {
#       std::cout << selected[s].id << " " << selected[s].weight << " " << selected[s].value << std::endl;
#     }
#
#    return 0;
#
# }
# Out:
# Overwriting mochila.cpp

# %%
# !g++ -o mochila mochila.cpp

# %%
# !./mochila < "in1.txt" > "out1.txt"

# %%
# !./mochila < "in1.txt"
# Out:
# -177503512 1 98
# -177503512 4 91
# -177503512 5 77
